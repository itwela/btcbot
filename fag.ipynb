# %%
import pandas as pd

# Load your CSV file into a DataFrame
df = pd.read_csv('dataset.csv')

# Define a function to apply background color based on conditions

df.style.background_gradient(cmap='RdYlGn_r', subset=['Value'])
# Out:
# <style type="text/css">
# #T_3a1ec_row0_col1, #T_3a1ec_row7_col1, #T_3a1ec_row52_col1, #T_3a1ec_row110_col1, #T_3a1ec_row335_col1, #T_3a1ec_row354_col1, #T_3a1ec_row564_col1, #T_3a1ec_row572_col1, #T_3a1ec_row610_col1, #T_3a1ec_row658_col1, #T_3a1ec_row1321_col1, #T_3a1ec_row1478_col1, #T_3a1ec_row1509_col1, #T_3a1ec_row1528_col1, #T_3a1ec_row1629_col1, #T_3a1ec_row1634_col1, #T_3a1ec_row1635_col1, #T_3a1ec_row1645_col1, #T_3a1ec_row1648_col1, #T_3a1ec_row1649_col1, #T_3a1ec_row1659_col1, #T_3a1ec_row1730_col1, #T_3a1ec_row1734_col1, #T_3a1ec_row1735_col1, #T_3a1ec_row1736_col1, #T_3a1ec_row1737_col1, #T_3a1ec_row1777_col1, #T_3a1ec_row1806_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# ...
